# %% [markdown]
# # Práctica Clase 6

# %% [markdown]
# 1) Cargar el dataset "Emisiones_CO2.csv" provisto en la clase 2 en un Dataframe de Pandas, quitar los registros que contengan valores faltantes e implementar una nueva columna, que contenga el resultado de una función Hash aplicada sobre el campo "Código de País" y se denomine "Clave_Hash".<br>
# Consideraciones: Se puede utilizar la función provista.

# %%
def hash_function(key):
    return sum(index * ord(character) for index, character in enumerate(repr(key), start=1))

# %%
print(hash_function('pato'))
print(hash_function('tapo'))
# Out:
# 1807
# 1799

# %%
import pandas as pd

# %%
df = pd.read_csv('F:/Modulo 1 de Data/Lecture 6_/Emisiones_CO2.csv',sep='|',decimal=',', encoding='latin-1')

# %%
import pandas as pd  
import os
s=open('F:/Modulo 1 de Data/Lecture 6_/Emisiones_CO2.csv','r')
next(s)
lista=[]
columnas=['Codigo de pais','Nombre del pais','Region','Año','CO2(kt)','CO2 per capita (toneladas metricas)']
lista1=[]

for i in s:
  a=i.strip().split('|')
  lista.append(a)
w=pd.DataFrame(data=lista,columns=columnas)
w1=w.drop(['CO2(kt)','CO2 per capita (toneladas metricas)'],axis=1)
new_data={'Clave_Hash':lista1}
def hash_function(key):
    return sum(index * ord(character) for index, character in enumerate(repr(key), start=1))
for indices, i in w1['Codigo de pais'].items():
    lista1.append(hash_function(i))

w1['Clave_Hash'] = lista1
w1
# Out:
#       Codigo de pais Nombre del pais                   Region   Año  \
# 0                ABW           Aruba  América Latina y Caribe  1960
# 1                ABW           Aruba  América Latina y Caribe  1961
# 2                ABW           Aruba  América Latina y Caribe  1962
# 3                ABW           Aruba  América Latina y Caribe  1963
# 4                ABW           Aruba  América Latina y Caribe  1964
# ...              ...             ...                      ...   ...
# 11122            ZWE        Zimbabue      África subsahariana  2007
# 11123            ZWE        Zimbabue      África subsahariana  2008
# 11124            ZWE        Zimbabue      África subsahariana  2009
# 11125            ZWE        Zimbabue      África subsahariana  2010
# 11126            ZWE        Zimbabue      África subsahariana  2011
#
#        Clave_Hash
# 0             910
# 1             910
# 2             910
# 3             910
# 4             910
# ...           ...
# ...

# %% [markdown]
# 2. A partir del Dataframe creado en el punto 1, construir uno nuevo, que contenga solo los valores distintos de la tupla "Clave_Hash", "Código de País" , "Nombre de país" y "Región". Quitando luego del dataframe original los campos "Código de País" , "Nombre de país" y "Región"

# %%
s=w1.drop('Año',axis=1)
s
# Out:
#       Codigo de pais Nombre del pais                   Region  Clave_Hash
# 0                ABW           Aruba  América Latina y Caribe         910
# 1                ABW           Aruba  América Latina y Caribe         910
# 2                ABW           Aruba  América Latina y Caribe         910
# 3                ABW           Aruba  América Latina y Caribe         910
# 4                ABW           Aruba  América Latina y Caribe         910
# ...              ...             ...                      ...         ...
# 11122            ZWE        Zimbabue      África subsahariana         951
# 11123            ZWE        Zimbabue      África subsahariana         951
# 11124            ZWE        Zimbabue      África subsahariana         951
# 11125            ZWE        Zimbabue      África subsahariana         951
# 11126            ZWE        Zimbabue      África subsahariana         951
#
# [11127 rows x 4 columns]

# %%
w
# Out:
#       Codigo de pais Nombre del pais                   Region   Año   CO2(kt)  \
# 0                ABW           Aruba  América Latina y Caribe  1960
# 1                ABW           Aruba  América Latina y Caribe  1961
# 2                ABW           Aruba  América Latina y Caribe  1962
# 3                ABW           Aruba  América Latina y Caribe  1963
# 4                ABW           Aruba  América Latina y Caribe  1964
# ...              ...             ...                      ...   ...       ...
# 11122            ZWE        Zimbabue      África subsahariana  2007  9.732,22
# 11123            ZWE        Zimbabue      África subsahariana  2008  7.682,37
# 11124            ZWE        Zimbabue      África subsahariana  2009  8.239,75
# 11125            ZWE        Zimbabue      África subsahariana  2010  9.028,15
# 11126            ZWE        Zimbabue      África subsahariana  2011  9.860,56
#
#       CO2 per capita (toneladas metricas)
# 0
# 1
# 2
# 3
# 4
# ...
